# %%
# %pip install --upgrade --quiet  transformers --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline
from langchain.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="bigscience/bloom-1b7",
    task="text-generation",
    device=0,  # -1 for CPU
    batch_size=2,  # adjust as needed based on GPU map and model size.
    model_kwargs={"temperature": 0, "max_length": 64},
)

gpu_chain = prompt | gpu_llm.bind(stop=["\n\n"])

questions = []
for i in range(4):
    questions.append({"question": f"What is the number {i} in french?"})

answers = gpu_chain.batch(questions)
for answer in answers:
    print(answer)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 gpu_llm = HuggingFacePipeline.from_model_id(
#       2     model_id="bigscience/bloom-1b7",
#       3     task="text-generation",
#       4     device=0,  # -1 for CPU
#       5     batch_size=2,  # adjust as needed based on GPU map and model size.
#       6     model_kwargs={"temperature": 0, "max_length": 64},
#       7 )
#       9 gpu_chain = prompt | gpu_llm.bind(stop=["\n\n"])
#      11 questions = []
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\langchain_community\llms\huggingface_pipeline.py:152, in HuggingFacePipeline.from_model_id(cls, model_id, task, device, device_map, model_kwargs, pipeline_kwargs, batch_size, **kwargs)
#     148     _model_kwargs = {
#     149         k: v for k, v in _model_kwargs.items() if k != "trust_remote_code"
#     150     }
#     151 _pipeline_kwargs = pipeline_kwargs or {}
# --> 152 pipeline = hf_pipeline(
#     153     task=task,
#     154     model=model,
#     155     tokenizer=tokenizer,
#     156     device=device,
#     157     device_map=device_map,
#     158     batch_size=batch_size,
#     159     model_kwargs=_model_kwargs,
#     160     **_pipeline_kwargs,
#     161 )
#     162 if pipeline.task not in VALID_TASKS:
#     163     raise ValueError(
#     164         f"Got invalid task {pipeline.task}, "
#     165         f"currently only {VALID_TASKS} are supported"
#     166     )
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\transformers\pipelines\__init__.py:1070, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1067 if device is not None:
#    1068     kwargs["device"] = device
# -> 1070 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\transformers\pipelines\text_generation.py:70, in TextGenerationPipeline.__init__(self, *args, **kwargs)
#      69 def __init__(self, *args, **kwargs):
# ---> 70     super().__init__(*args, **kwargs)
#      71     self.check_model_type(
#      72         TF_MODEL_FOR_CAUSAL_LM_MAPPING_NAMES if self.framework == "tf" else MODEL_FOR_CAUSAL_LM_MAPPING_NAMES
#      73     )
#      74     if "prefix" not in self._preprocess_params:
#      75         # This is very specific. The logic is quite complex and needs to be done
#      76         # as a "default".
#      77         # It also defines both some preprocess_kwargs and generate_kwargs
#      78         # which is why we cannot put them in their respective methods.
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\transformers\pipelines\base.py:840, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#     833 # We shouldn't call `model.to()` for models loaded with accelerate
#     834 if (
#     835     self.framework == "pt"
#     836     and self.device is not None
#     837     and not (isinstance(self.device, int) and self.device < 0)
#     838     and hf_device_map is None
#     839 ):
# --> 840     self.model.to(self.device)
#     842 # Update config and generation_config with task specific parameters
#     843 task_specific_params = self.model.config.task_specific_params
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\transformers\modeling_utils.py:2595, in PreTrainedModel.to(self, *args, **kwargs)
#    2590     if dtype_present_in_args:
#    2591         raise ValueError(
#    2592             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2593             " `dtype` by passing the correct `torch_dtype` argument."
#    2594         )
# -> 2595 return super().to(*args, **kwargs)
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\torch\nn\modules\module.py:1160, in Module.to(self, *args, **kwargs)
#    1156         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                     non_blocking, memory_format=convert_to_format)
#    1158     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1160 return self._apply(convert)
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\torch\nn\modules\module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\torch\nn\modules\module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 810 (2 times)]
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\torch\nn\modules\module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\torch\nn\modules\module.py:833, in Module._apply(self, fn, recurse)
#     829 # Tensors stored in modules are graph leaves, and we don't want to
#     830 # track autograd history of `param_applied`, so we have to use
#     831 # `with torch.no_grad():`
#     832 with torch.no_grad():
# --> 833     param_applied = fn(param)
#     834 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     835 if should_use_set_data:
#
# File c:\Users\alanj\Documents\GitHub\dynolearn\venv\Lib\site-packages\torch\nn\modules\module.py:1158, in Module.to.<locals>.convert(t)
#    1155 if convert_to_format is not None and t.dim() in (4, 5):
#    1156     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                 non_blocking, memory_format=convert_to_format)
# -> 1158 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
